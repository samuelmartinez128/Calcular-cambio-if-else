# %% [markdown]
# <a href="https://colab.research.google.com/github/samuelmartinez128/Calcular-cambio-if-else/blob/main/Elprofe_Act_12_Cambio_Alumno_Samuel_Martinez.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Samuel Martinez NL = 35 Fecha 26/mar/2026
# ### Calculando cambio usando if else
# ### Mirar diagrama de flujo
# <img src="https://raw.githubusercontent.com/samuelmartinez128/Calcular-cambio-if-else/refs/heads/main/imagen%207.jpg" width="200" height="200">
#
# ## Las variables
# 1. CP = Costo del producto
# 2. CD = Cantidad de dinero
# 3. Cambio
#
# ## Formulas
# $Cambio = CD - CP$
#
# ## Diagrama de flujo LucidChart
# <img src="https://raw.githubusercontent.com/samuelmartinez128/Calcular-cambio-if-else/refs/heads/main/DF%20if%20else%20cambio2.png"
# alt="perrito negro" width="350" height="500">

# %%
# para cuando sea verdadero (si)
# Calculando el cambio usando if else
# Datod de entrada CD, CP
# mostrar Cambio si es falso
# si es verdadero mostrar No alcanza
CP = float(input("Ingrese el costo del producto: "))
CD = float(input("Ingrese la cantidad de dinero: "))
if CP > CD:
  print("No alcanza")
else:
  Cambio = CD - CP
  print("El cambio es: ", Cambio)
print("Fin del programa")
print("Programa realizado por Samuel Martinez NL = 35")
# Out:
# Ingrese el costo del producto: 500
# Ingrese la cantidad de dinero: 400
# No alcanza
# Fin del programa
# Programa realizado por Samuel Martinez NL = 35

# %%
# para cuando sea falso (no)
# Calculando el cambio usando if else
# Datod de entrada CD, CP
# mostrar Cambio si es falso
# si es verdadero mostrar No alcanza
CP = float(input("Ingrese el costo del producto: "))
CD = float(input("Ingrese la cantidad de dinero: "))
if CP > CD:
  print("No alcanza")
else:
  Cambio = CD - CP
  print("El cambio es: ", Cambio)
print("Fin del programa")
print("Programa realizado por Samuel Martinez NL = 35")
# Out:
# Ingrese el costo del producto: 250
# Ingrese la cantidad de dinero: 300
# El cambio es:  50.0
# Fin del programa
# Programa realizado por Samuel Martinez NL = 35

# %% [markdown]
# ## Relacion entre codigo y diagrama de flujo
# <img src="https://raw.githubusercontent.com/samuelmartinez128/Calcular-cambio-if-else/refs/heads/main/TLDraw%20codigo%20DF.png"
# alt="perrito negro" width="800" height="500">
